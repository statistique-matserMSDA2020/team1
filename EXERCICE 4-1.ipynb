# %% [markdown]
# Membres du grgoupes:Amy DIAO
#                     Louis Isacc Jean Samba DIOUF
#                     Marie Marone M.L.M FAYE

# %%
import numpy as np

import matplotlib.pylab as plt




N = 10000
x = np.random.random(size=N)
y = np.random.random(size=N)

z=(1-(x**2))<1

pi_est = 4*z.sum()/N

print('Estimation de pi:{}'.format(pi_est))

fig, ax =plt.subplots(1,1,figsize=(5,5))

plt.scatter(x[z], y[z], marker='.')

nz = np.logical_not(z)
plt.scatter(x[nz], y[nz], marker='.')

ax.set(title=r"calcul de N par la methode de monte carlo.",
       xlabel="x",
       ylabel='y')

fig.savfig('monte_carlo.png')
# Out:
# Estimation de pi:4.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7c0d1635d344> in <module>
#      27        ylabel='y')
#      28
# ---> 29 fig.savfig('monte_carlo.png')
#      30
#
# AttributeError: 'Figure' object has no attribute 'savfig'

# %%
import numpy as np

import matplotlib.pylab as plt




N = 10000
x = np.random.random(size=N)
y = np.random.random(size=N)

z=(1-(x**2))<1

pi_est = 4*z.sum()/N

print('Estimation de pi:{}'.format(pi_est))

fig, ax =plt.subplots(1,1,figsize=(5,5))

plt.scatter(x[z], y[z], marker='.')

nz = np.logical_not(z)
plt.scatter(x[nz], y[nz], marker='.')

ax.set(title=r"calcul de N par la methode de monte carlo.",
       xlabel="x",
       ylabel='y')

fig.savfig('monte_carlo.png')
# Out:
# Estimation de pi:4.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-7c0d1635d344> in <module>
#      27        ylabel='y')
#      28
# ---> 29 fig.savfig('monte_carlo.png')
#      30
#
# AttributeError: 'Figure' object has no attribute 'savfig'
